# %%
import random
import csv


def main():
    hun =[0,0,0,0,0,0]
    tho = [0,0,0,0,0,0]
    tentho = [0,0,0,0,0,0]
    huntho = [0,0,0,0,0,0]

    for i in range(100):
        r = random.randint(1,6) 
        if(r==1):
            hun[0]+=1
        if(r==2):
            hun[1]+=1
        if(r==3):
            hun[2]+=1
        if(r==4):
            hun[3]+=1
        if(r==5):
            hun[4]+=1
        if(r==6):
            hun[5]+=1
    for i in range(1000):
        r = random.randint(1,6) 
        if(r==1):
            tho[0]+=1
        if(r==2):
            tho[1]+=1
        if(r==3):
            tho[2]+=1
        if(r==4):
            tho[3]+=1
        if(r==5):
            tho[4]+=1
        if(r==6):
            tho[5]+=1
    for i in range(10000):
        r = random.randint(1,6) 
        if(r==1):
            tentho[0]+=1
        if(r==2):
            tentho[1]+=1
        if(r==3):
            tentho[2]+=1
        if(r==4):
            tentho[3]+=1
        if(r==5):
            tentho[4]+=1
        if(r==6):
            tentho[5]+=1
    for i in range(100000):
        r = random.randint(1,6) 
        if(r==1):
            huntho[0]+=1
        if(r==2):
            huntho[1]+=1
        if(r==3):
            huntho[2]+=1
        if(r==4):
            huntho[3]+=1
        if(r==5):
            huntho[4]+=1
        if(r==6):
            huntho[5]+=1

    f = open('dice.csv','w', newline='')
    f.write('빈도, 1, 2, 3, 4, 5, 6')
    f.write("\n100")
    for i in hun: 
        f.write(","+str(i))
    f.write("\n1000")
    for i in tho: 
        f.write(","+str(i))
    f.write("\n10000")
    for i in tentho: 
        f.write(","+str(i))
    f.write("\n100000")
    for i in huntho: 
        f.write(","+str(i))
    f.close()
    print("파일 생성 완료")
 
if __name__ == '__main__':

    main()
# Out:
# 파일 생성 완료

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False



def main():

    a1=[]
    a2=[]
    a3=[]
    a4=[]

    xlist=[1,2,3,4,5,6]

    f=open('dice.csv')
    data = csv.reader(f)
    header=next(data)

    for row in data:
        if row[0]=='100':
            for i in range(1, 7):
                a1.append(int(row[i]))
        if row[0]=='1000':
            for i in range(1, 7):
                a2.append(int(row[i]))
        if row[0]=='10000':
            for i in range(1, 7):
                a3.append(int(row[i]))
        if row[0]=='100000':
            for i in range(1, 7):
                a4.append(int(row[i]))

    xlist=[1,2,3,4,5,6]



    plt.figure(figsize = (10, 5))
    plt.bar(xlist, a1)
    plt.title('주사위 시행 100')
    plt.xlabel('주사위 면')
    plt.ylabel('횟수')
    plt.show()


    plt.figure(figsize = (10, 5))
    plt.bar(xlist, a2)
    plt.title('주사위 시행 1000')
    plt.xlabel('주사위 면')
    plt.ylabel('횟수')
    plt.show()

    plt.figure(figsize = (10, 5))
    plt.bar(xlist, a3)
    plt.title('주사위 시행 10000')
    plt.xlabel('주사위 면')
    plt.ylabel('횟수')
    plt.show()

    plt.figure(figsize = (10, 5))
    plt.bar(xlist, a4)
    plt.title('주사위 시행 100000')
    plt.xlabel('주사위 면')
    plt.ylabel('횟수')
    plt.show()

 

if __name__ == '__main__':

 

    main()
# Out:
# Hello, World!
