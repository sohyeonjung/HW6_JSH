# %%
import random
import csv
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False


hun =[]
tho = []
tentho = []
huntho = []

f = open('dice.csv','w', newline='')
f.write("100")
for i in range(100):
    r = random.randint(1,6)  
    f.write(","+str(r))
f.write("\n1000")
for i in range(1000):
    r = random.randint(1,6)  
    f.write(","+str(r))
f.write("\n10000")
for i in range(10000):
    r = random.randint(1,6)  
    f.write(","+str(r))
f.write("\n100000")
for i in range(100000):
    r = random.randint(1,6)  
    f.write(","+str(r))
f.close()

f=open('dice.csv')
data = csv.reader(f)
next(data)

l=100
for row in data:
    if(l==100):
        for i in range(1,l+1):
            hun.append(row[i])
    if(l==1000):
        for i in range(1,l+1):
            tho.append(row[i])
    if(l==10000):
        for i in range(1,l+1):
            tentho.append(row[i])
    if(l==100000):
        for i in range(1,l+1):
            huntho.append(row[i])
    l*=10

print(huntho)

xlist=[1,2,3,4,5,6]








    
print("End")
# Out:
# []
# End

# %%
import random
import csv


def main():
    hun =[0,0,0,0,0,0]
    tho = [0,0,0,0,0,0]
    tentho = [0,0,0,0,0,0]
    huntho = [0,0,0,0,0,0]

    for i in range(100):
        r = random.randint(1,6) 
        if(r==1):
            hun[0]+=1
        if(r==2):
            hun[1]+=1
        if(r==3):
            hun[2]+=1
        if(r==4):
            hun[3]+=1
        if(r==5):
            hun[4]+=1
        if(r==6):
            hun[5]+=1
    for i in range(1000):
        r = random.randint(1,6) 
        if(r==1):
            tho[0]+=1
        if(r==2):
            tho[1]+=1
        if(r==3):
            tho[2]+=1
        if(r==4):
            tho[3]+=1
        if(r==5):
            tho[4]+=1
        if(r==6):
            tho[5]+=1
    for i in range(10000):
        r = random.randint(1,6) 
        if(r==1):
            tentho[0]+=1
        if(r==2):
            tentho[1]+=1
        if(r==3):
            tentho[2]+=1
        if(r==4):
            tentho[3]+=1
        if(r==5):
            tentho[4]+=1
        if(r==6):
            tentho[5]+=1
    for i in range(100000):
        r = random.randint(1,6) 
        if(r==1):
            huntho[0]+=1
        if(r==2):
            huntho[1]+=1
        if(r==3):
            huntho[2]+=1
        if(r==4):
            huntho[3]+=1
        if(r==5):
            huntho[4]+=1
        if(r==6):
            huntho[5]+=1

    f = open('dice.csv','w', newline='')
    f.write('빈도, 1, 2, 3, 4, 5, 6')
    f.write("\n100")
    for i in hun: 
        f.write(","+str(i))
    f.write("\n1000")
    for i in tho: 
        f.write(","+str(i))
    f.write("\n10000")
    for i in tentho: 
        f.write(","+str(i))
    f.write("\n100000")
    for i in huntho: 
        f.write(","+str(i))
    f.close()
    print("파일 생성 완료")
 
if __name__ == '__main__':

    main()
# Out:
# 파일 생성 완료

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

a1=[]
a2=[]
a3=[]
a4=[]

xlist=[1,2,3,4,5,6]

f=open('dice.csv')
data = csv.reader(f)
header=next(data)
print(header)

for row in data:
    if row[0]=='100':
        for i in range(1, 7):
            a1.append(int(row[i]))
    if row[0]=='1000':
        for i in range(1, 7):
            a2.append(int(row[i]))
    if row[0]=='10000':
        for i in range(1, 7):
            a3.append(int(row[i]))
    if row[0]=='100000':
        for i in range(1, 7):
            a4.append(int(row[i]))
            
xlist=[1,2,3,4,5,6]

# 히스토그램 그리기
data = [a1, a2, a3, a4]
count = [100, 1000, 10000, 100000]

fig, axs = plt.subplots(nrows=len(count), ncols=1, figsize=(8, 3 * len(count)))

x_labels = ['1', '2', '3', '4', '5', '6']
x = np.arange(len(x_labels))

for i, ax in enumerate(axs):
    ax.hist(x + 0.5, bins=np.arange(len(x_labels) + 1), weights=data[i], label=str(count[i]), color='lightgray', alpha=0.7, rwidth=1.0)
    for j, v in enumerate(data[i]):
        ax.text(j + 0.5, v + 0.5, str(v), color='black', ha='center', va='center')
    ax.set_title('Dice Roll (Count={})'.format(count[i]))
    ax.legend(loc='lower center')
    ax.set_xticks(x + 0.5)
    ax.set_xticklabels(x_labels)

plt.subplots_adjust(wspace=0.3, hspace=0.3)

plt.show()
# Out:
# ['빈도', ' 1', ' 2', ' 3', ' 4', ' 5', ' 6']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 40
#      37 fig, axs = plt.subplots(nrows=len(count), ncols=1, figsize=(8, 3 * len(count)))
#      39 x_labels = ['1', '2', '3', '4', '5', '6']
# ---> 40 x = np.arange(len(x_labels))
#      42 for i, ax in enumerate(axs):
#      43     ax.hist(x + 0.5, bins=np.arange(len(x_labels) + 1), weights=data[i], label=str(count[i]), color='lightgray', alpha=0.7, rwidth=1.0)
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt

# x, y값 설정
x = [1, 2, 3, 4, 5]
y = [10, 7, 5, 3, 1]

# 히스토그램 그리기
plt.hist(y, bins=len(x))
plt.xticks(x)
plt.show()
